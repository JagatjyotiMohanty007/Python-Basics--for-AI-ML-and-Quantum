# %%
a = 5
type(a)
# Out:
# int

# %%
a = 5
print(type(a))
# Out:
# <class 'int'>

# %%
l = [1,2,4]
print(type(l))
# Out:
# <class 'list'>

# %%
def config():
    print('hello team')
config()
# Out:
# hello team

# %%
class laptop(): #laptop is class name 
    def config(): #config is method name 
        print('hello team') # statment 

lap = laptop() # lap - cobject

# %%
class laptop(): 
    def config(): 
        print('hello team') 

lap = laptop() 

laptop.config()
# Out:
# hello team

# %%
class laptop(): 
    def config(self): 
        print('hello team') 

lap = laptop() 
lap.config()
# Out:
# hello team

# %%
class laptop(): 
    def config(self): 
        print('hello team') 

lap = laptop() 

lap.config()
# Out:
# hello team

# %%
class laptop(): 
    def config(self): 
        print('hello team') 

lap = laptop() 
lap1 = laptop()
lap2 = laptop()

lap.config()
lap1.config()
lap2.config()
# Out:
# hello team
# hello team
# hello team

# %%
class computer():     # computer is the class
    def config(self):   # config is the methos   
        print('i5', '8gb')

com1 = computer()
com2 = computer()
com3 = computer()

print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# 2911044734752
# 2911044740512
# 2911044736240

# %%
class computer():        # computer is class (user create the class hear(user defind class)
    def lap():      # confit is method (define some method hear so when we talk class always method will come ( so dont talk about function hear)
        print('i5', '8gb') # i want to print configuration of the machine which i5 ram & 8gb ram
    
a = '8.8'
print(type(a)) 

com1 = computer() #com1 is the user define object of the computer class but if you check above a is the object for string data type & in java we called this as constructor
print(type(com1))
# Out:
# <class 'str'>
# <class '__main__.computer'>

# %% [markdown]
# # special method

# %%
class computer():        
    def config(self):      
        print('i5', '8gb')

com1 = computer()

# %%
class computer():        
    def __init__(self):      
        print('i5', '8gb')

com1 = computer()
com2 = computer()
# Out:
# i5 8gb
# i5 8gb

# %%
class computer():        
    def __init__(self):      
        print('i5', '8gb')

com1 = computer()
com2 = computer()

com1.__init__()
# Out:
# i5 8gb
# i5 8gb
# i5 8gb

# %%
class computer:        
    
    def __init__(self): #__init__ means initialize the varible
        print('in init')
        
com1 = computer()
com2 = computer()
com3 = computer()
# Out:
# in init
# in init
# in init

# %%
class computer():
    
    def __init__(self): #__init__ means initialize the varible
        print('in init')

    def computer(self):
        print('i5', 8)
        
com1 = computer()
# Out:
# in init

# %%
class computer():
    
    def __init__(self): #__init__ means initialize the varible
        print('in init')

    def computer(self):
        print('i5', 8)
        
com1 = computer()  
com1.computer()
# Out:
# in init
# i5 8

# %%
class computer():        
    def config(self):     
        print('i5', '8gb')

    def config2(self):
        print('i7', '32gb')

    def __init__(self):
        print('in init')

com1 = computer()
com2 = computer()

com1.config() 
com1.config2()
# Out:
# in init
# in init
# i5 8gb
# i7 32gb

# %%
class computer():        
    
    def __init__(self, ram, memory, price): #__init__ means to initialize the variable
        self.ram = ram
        self.memory = memory
        self.price = price
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer('i5', 8, 20000) # com1 has cpu i5 & ram is 8 

com1.config()
# Out:
# in init
# i5 8gb

# %%
class computer():        
    
    def __init__(self,memory, ram): #__init__ means to initialize the variable
        self.ram = ram
        self.memory = memory
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer('i5', 8) # com1 has cpu i5 & ram is 8 
com2 = computer('i7', 16) # com2 has cpu intel 5 & ram is 8 as we have 2 computer we have different ram & cpt

com1.config() 
com2.config()
# Out:
# in init
# in init
# i5 8gb
# i5 8gb

# %%
class computer():        
    
    def __init__(self,cpu,ram,price): #__init__ means to initialize the variable
        print('in init')
    
    def config(self):     
        print('i5', '8gb', 5000)

com1 = computer('i5', 8, 50000) # com1 has cpu i5 & ram is 8 
com2 = computer('i7', 16, 60000) # com2 has cpu intel 5 & ram is 8 as we have 2 computer we have different ram & cpt

com1.config() 
com2.config()
# Out:
# in init
# in init
# i5 8gb 5000
# i5 8gb 5000

# %%
class computer():        
     
    def __init__(self,cpu,ram): # cpu & ram as argument
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
 
    def config(self):     
        print('config is', self.cpu, self.ram) 

com1 = computer('i5', 8)
com2 = computer('i7', 16)


com1.config() 
com2.config()

#print(id(com1))
#print(id(com2))
# Out:
# config is i5 8
# config is i7 16

# %%
class computer():        
     
    def __init__(self,cpu,ram,price ): # cpu & ram as argument
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
        self.price = price
 
    def config(self):     
        print('config is', self.cpu, self.ram, self.price ) 

com1 = computer('i5', 8, 1000)
com2 = computer('i7', 16, 2000)

com1.config() 
com2.config()
# Out:
# config is i5 8 1000
# config is i7 16 2000

# %%
class computer():        
     
    def __init__(self, cpu, ram, price, company ): # cpu & ram as argument
        
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
        self.price = price
        self.company= company
 
    def config(self):     
        print('config is', self.cpu, self.ram, self.price , self.company) 

com1 = computer('i5', 8, 1000, 'len' )
com2 = computer('i7', 16, 2000,'hp')

com1.config() 
com2.config()
# Out:
# config is i5 8 1000 len
# config is i7 16 2000 hp

# %%
class computer():
    def __init__(self):
        self.name = 'akash'
        self.age = 37

c1 = computer()
c2 = computer()

print(c1.name,c1.age)
print(c2.name)
# Out:
# akash 37
# akash

# %%
class computer():
    def __init__(self):
        self.name = 'akash'
        self.age = 37

c1 = computer()
c2 = computer()

c2.name = 'ramesh'
c2.age = 45
c1.age = 35

print(c1.name,c1.age)
print(c2.name, c2.age)
# Out:
# akash 35
# ramesh 45
