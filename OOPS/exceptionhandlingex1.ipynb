# %% [markdown]
# Exception Handling in Python

# %%
a = 5
b = 2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c = 5
d = 0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
c = 5
d = 0
print('bye')
print(c/d)
# Out:
# bye
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 c = 5
#       2 d = 0
#       3 print('bye')
# ----> 4 print(c/d)
#
# ZeroDivisionError: division by zero

# %%
c = 5
d = 0
print(c/d)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 c = 5
#       2 d = 0
# ----> 3 print(c/d)
#       4 print('bye')
#
# ZeroDivisionError: division by zero

# %%
c = 3
d = 0
try:
    print(c/d)    # if thisi code give error then except the exception and print the message  
except Exception: 
    print('hey you cannot divide Number by zero')
print('bye')
# Out:
# hey you cannot divide Number by zero
# bye

# %%
c = 3
d = 3
try:
    print(c/d)

except Exception:
    print('hey you cannot divide Number by zero')

print('bye')
      # except blok will execute only when you entere the error
# Out:
# 1.0
# bye

# %%
# if i print the error message as well along with message 
c = 3
d = 3

try:
    print(c/d)
    
except Exception as e :
    print('hey you cannot divide Number by zero',  e)

print('bye')
# Out:
# 1.0
# bye

# %%
# if i print the error message as well along with message 
c = 3
d = 0

try:
    print(c/d)
    
except Exception as e :
    print('hey you cannot divide Number by zero',':',  e)

print('bye')
# Out:
# hey you cannot divide Number by zero : division by zero
# bye

# %%
c = 3
d = 3
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    print('resoruce closed')
  
except Exception as e :
    print('hey you cannot divide Number by zero',':', e)
# Out:
# resource open
# 1.0
# resoruce closed

# %%
c = 3
d = 0
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    print('resource closed')
   
except Exception as e :
    print('hey you cannot divide Number by zero', ':', e)   
# if you see the output then resource is open but resource is not closed hear at exception block
# Out:
# resource open
# hey you cannot divide Number by zero : division by zero

# %%
# if i print the error message as well along with message 
c = 3
d = 0

try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    
except Exception as e :
    print('hey you cannot divide Number by zero',':', e)   
    print('resource closed')
# if you see the output then resource is open but resource is not closed hear at exception block
# Out:
# resource open
# hey you cannot divide Number by zero : division by zero
# resource closed

# %%
# if i print the error message as well along with message 
c = 3
d = 3

try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
 
except Exception as e :
    print('hey you cannot divide Number by zero',  e)   
    print('resource closed')
# in this case we not got closed
# that mean if we dont have error then execute block will not execute
# that is the problem that means can we put both print'resource closed but this is not the right way 
# thats why we introduce FINALLY
# Out:
# resource open
# 1.0

# %%
# if i print the error message as well along with message 
c = 3
d = 3

try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    print('resource closed')
    
except Exception as e :
    print('hey you cannot divide Number by zero',':', e)   
    print('resource closed')
    
# in this case we not got closed
# that mean if we dont have error then execute block will not execute
# that is the problem that means can we put both print'resource closed but this is not the right way 
# thats why we introduce FINALLY
# Out:
# resource open
# 1.0
# resource closed

# %%
c = 3
d = 3
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
 
except Exception as e :
    print('hey you cannot divide Number by zero', ':', e)   
    print('resource closed')
  
finally:
    print('resource closed')
# it does not matter about any block finally it will execute
# Out:
# resource open
# 1.0
# resource closed

# %%
c = 3
d = 0
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
except Exception as e :
    print('hey you cannot divide Number by zero',  e)   
    #print('resource closed')
finally:
    print('resource closed')
# it does not matter about any block finally it will execute
# Out:
# resource open
# hey you cannot divide Number by zero division by zero
# resource closed

# %%
c = 3
d = 3

try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    k = int(input('enter the number'))
    print(k)
   
except Exception as e :
    print('hey you cannot divide Number by zero',  e)   
    #print('resource closed')
finally:
    print('resource closed')
# Out:
# resource open
# 1.0
# 5
# resource closed

# %%
c = 3
d = 0

try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    k = int(input('enter the number'))
    print(k)
   
except Exception as e :
    print('hey you cannot divide Number by zero',  e)   
    print('resource closed')
finally:
    print('resource closed')
# Out:
# resource open
# hey you cannot divide Number by zero division by zero
# resource closed
# resource closed

# %%
c = 3
d = 3

k = int(input('enter the number'))
print(k)
    
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
 
except Exception as e :
    print('hey you cannot divide Number by zero',  e)   
    print('resource closed')
finally:
    print('resource closed')
# Out:
# 6
# resource open
# 1.0
# resource closed

# %%
c = 3
d = 0
  
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    k = int(input('enter the number'))
    print(k)
 #hear we are trying handle zero division error 
except ZeroDivisionError as e :
    print('hey you cannot divide Number by zero',  e)   
    # hear we trying to handle value error
    
except ValueError as e:
    print('invalid input')
    
    # what happen the error which you dont know about it which are not is zero division error & values erro 
    # i mean if you go to dentist, skin specialist, finaly you go to the general physician
    # this exception can handle all other exception 
except Exception as e:
    print('something is wrrong..')
    

finally:
    print('resource closed')
# Out:
# resource open
# hey you cannot divide Number by zero division by zero
# resource closed
