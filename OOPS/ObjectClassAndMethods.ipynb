# %%
a =5
type(a)
# Out:
# int

# %%
def config():
    print("hello team")
config()
# Out:
# hello team

# %%
class laptop():
    def config():
        print("Hello")
lap = laptop()
laptop.config()
#lap.config()
# Out:
# Hello

# %%
class laptop():
    def config(self):
        print("Hello")
lap = laptop()
#laptop.config()
lap.config()
# Out:
# Hello

# %%
class laptop():
    def config(self):
        print("Hello")
lap = laptop()
lap1 = laptop()
lap2 = laptop()
#laptop.config()
lap.config()
lap1.config()
lap2.config()
# Out:
# Hello
# Hello
# Hello

# %%
class computer():
    def config(self):
        print("Computer")
a=8.8
print(type(a))
com1 = computer()
com2 = computer()
com3 = computer()
#laptop.config()
print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# <class 'float'>
# 2539776757680
# 2539776768096
# 2539776768192

# %%
class computer():
    def conf(self):
        print("Computer")
com1 = computer()
com1.conf()
# Out:
# Computer

# %%
class computer1():
    def __init__(self):
        print("i5", "8GB")
com1 = computer1()
com2 = computer1()
com1.__init__()
# Out:
# i5 8GB
# i5 8GB
# i5 8GB

# %%
class computer2():
    def __init__(self):
        print("i5", "8GB")
com1 = computer2()
com2 = computer2()
com3 = computer2()
com1.__init__()
# Out:
# i5 8GB
# i5 8GB
# i5 8GB
# i5 8GB

# %%
class computer3():
    def __init__(self):
        print("i5", "8GB")
    def computer(self):
        print("i5",8)
com1 = computer3()
com1.computer()
# Out:
# i5 8GB
# i5 8

# %%
class computer4():
    def __init__(self):
        print("i5", "8GB")
    def computer(self):
        print("i5",8)
    def computer2(self):
        print("i5",18)
com1 = computer4()
com2 = computer4()
com1.computer()
com1.computer2()
# Out:
# i5 8GB
# i5 8GB
# i5 8
# i5 18

# %%
class computer5():
    def __init__(self,cpu,ram,price):
        print("i5", "8GB")
    def config(self):
        print("i5",8)
  
com1 = computer5('i5','8gb',50000)
com1 = computer5('i7','16gb',75000)
com1.config()
# Out:
# i5 8GB
# i5 8GB
# i5 8

# %%
class computer6():
    def __init__(self,cpu,ram,price,company):
        print("i5", "8GB")
        self.cpu =cpu
        self.ram = ram
        self.price = price
        self.company = company
    def config(self):
        print("Config is",self.cpu,self.ram,self.price, self.company)
  
com1 = computer6('i5','8gb',50000,'Lenovo')
com2 = computer6('i7','16gb',75000, 'HPE')
com1.config()
com2.config()
# Out:
# i5 8GB
# i5 8GB
# Config is i5 8gb 50000 Lenovo
# Config is i7 16gb 75000 HPE

# %%
class computer7():
    def __init__(self,cpu,ram,price,company):
        print("i5", "8GB")
        self.cpu =cpu
        self.ram = ram
        self.price = price
        self.company = company
    def config(self):
        print("Config is",self.cpu,self.ram,self.price, self.company)
  
com1 = computer7('i5','8gb',50000,'Lenovo')
com2 = computer7('i7','16gb',75000, 'HPE')
com1.config()
com2.config()

# %%
class computer8():
    def __init__(self):
        print("i5", "8GB")
        self.name ='Akash'
        self.age = 37
       
    def config(self):
        print("Config is",self.name,self.age)
  
com1 = computer8()
com2 = computer8()
com2.name ="Jagatjyoti"
com1.config()
com2.config()
# Out:
# i5 8GB
# i5 8GB
# Config is Akash 37
# Config is Jagatjyoti 37
